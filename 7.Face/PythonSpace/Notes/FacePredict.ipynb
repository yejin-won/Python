# %%
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
num_of_data = 1
img_width_size = 300
img_height_size = 400

# %%
testImage = np.zeros(num_of_data * img_width_size * img_height_size, dtype=np.int32).reshape(num_of_data,img_height_size,img_width_size)

# %%
img = np.array(Image.open("../Data/FaceGray/Aiden/image_0000.jpg"),dtype=np.int32)
testImage[0,:,:] = img

# %%
plt.imshow(testImage[0].reshape(400,300),cmap='gray')
plt.show()

# %%
dirNames = ['Aiden','Andrew','Cathy']
model2 = keras.models.load_model("../Data/CNN/best-gray-cnn-model.h5")
preds = model2.predict(testImage)
print(dirNames[np.argmax(preds[0])])
# Out:
# 2022-08-03 12:11:34.627679: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1/1 [==============================] - 0s 446ms/step
# Aiden
